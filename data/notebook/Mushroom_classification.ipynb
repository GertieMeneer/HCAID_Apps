# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import joblib

# %%
data = pd.read_csv("mushroom.csv")
print(data.head())
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
# 3            y          w         u          w        t         p
# 4            y          w         u          w        t         p
#
#   spore-print-color habitat season
# 0               NaN       d      w
# 1               NaN       d      u
# 2               NaN       d      w
# 3               NaN       d      w
# 4               NaN       d      w
#
# [5 rows x 21 columns]

# %%
categorical_columns = [
    'cap-shape', 'cap-surface', 'cap-color',
    'gill-attachment', 'gill-spacing', 'gill-color',
    'stem-root', 'stem-surface', 'stem-color',
    'veil-type', 'veil-color', 'has-ring', 'ring-type',
    'spore-print-color'
]


for col in categorical_columns:
    plt.figure(figsize=(8,4))
    
    data[col+'_filled'] = data[col].fillna('Missing')
    
    sns.countplot(x=col+'_filled', data=data, palette='viridis')
    plt.title(f'Counts of different values in {col} (including missing)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    
    print(f"\nValue counts for {col} (including missing):")
    print(data[col].value_counts(dropna=False))
# Out:
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for cap-shape (including missing):
# cap-shape
# x    26934
# f    13404
# s     7164
# b     5694
# o     3460
# p     2598
# c     1815
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for cap-surface (including missing):
# cap-surface
# NaN    14120
# t       8196
# s       7608
# y       6341
# h       4974
# g       4724
# d       4432
# e       2584
# k       2303
# i       2225
# w       2150
# l       1412
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for cap-color (including missing):
# cap-color
# n    24218
# y     8543
# w     7666
# g     4420
# e     4035
# o     3656
# r     1782
# u     1709
# p     1703
# k     1279
# b     1230
# l      828
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for gill-attachment (including missing):
# gill-attachment
# a      12698
# d      10247
# NaN     9884
# x       7413
# p       6001
# e       5648
# s       5648
# f       3530
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for gill-spacing (including missing):
# gill-spacing
# NaN    25063
# c      24710
# d       7766
# f       3530
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for gill-color (including missing):
# gill-color
# w    18521
# n     9645
# y     9546
# p     5983
# g     4118
# f     3530
# o     2909
# k     2375
# r     1399
# e     1066
# u     1023
# b      954
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for stem-root (including missing):
# stem-root
# NaN    51538
# s       3177
# b       3177
# r       1412
# f       1059
# c        706
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for stem-surface (including missing):
# stem-surface
# NaN    38124
# s       6025
# y       4940
# i       4396
# t       2644
# g       1765
# k       1581
# f       1059
# h        535
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for stem-color (including missing):
# stem-color
# w    22926
# n    18063
# y     7865
# g     2626
# o     2187
# e     2050
# u     1490
# f     1059
# p     1025
# k      837
# r      542
# l      226
# b      173
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for veil-type (including missing):
# veil-type
# NaN    57892
# u       3177
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for veil-color (including missing):
# veil-color
# NaN    53656
# w       5474
# y        527
# n        525
# u        353
# k        353
# e        181
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for has-ring (including missing):
# has-ring
# f    45890
# t    15179
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for ring-type (including missing):
# ring-type
# f      48361
# NaN     2471
# e       2435
# z       2118
# l       1427
# r       1399
# p       1265
# g       1240
# m        353
# Name: count, dtype: int64
# C:\Users\stefk\AppData\Local\Temp\ipykernel_6484\2287529897.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col+'_filled', data=data, palette='viridis')
# Value counts for spore-print-color (including missing):
# spore-print-color
# NaN    54715
# k       2118
# p       1259
# w       1212
# n       1059
# g        353
# u        182
# r        171
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='class', data=data)
plt.title("Distribution of Edible vs Poisonous Mushrooms")
plt.show()

# %%
encoded_data = data.copy()
for col in encoded_data.columns:
    encoded_data[col] = LabelEncoder().fit_transform(encoded_data[col])

plt.figure(figsize=(15,12))
sns.heatmap(encoded_data.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlations")
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

print(data.columns)

X = data.drop(['class', 'does-bruise-or-bleed', 'habitat', 'season', 'cap-surface', 'cap-color', 
               'gill-attachment', 'gill-spacing', 'gill-color', 'stem-root', 'veil-type', 'veil-color', 
               'has-ring', 'ring-type'], axis=1)
y = data['class']

X_encoded = pd.get_dummies(X, drop_first=True)
le_y = LabelEncoder()
y_encoded = le_y.fit_transform(y)

mushroom_example = X_encoded.iloc[17303]
class_example = y_encoded[17303]

print("Feature row (X):")
print(mushroom_example.to_string())
print("\nTarget value (y):")
print(class_example)

poisonous_data = data[data['class'] == 1]
edible_data = data[data['class'] == 0]

poisonous_sample = poisonous_data.sample(frac=0.6, random_state=42)
edible_sample = edible_data.sample(frac=0.4, random_state=42)

final_split = pd.concat([poisonous_sample, edible_sample])

print("Class distribution in final split:")
print(final_split['class'].value_counts(normalize=True))
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')
# Feature row (X):
# cap-diameter            8.95
# stem-height             7.67
# stem-width             30.78
# cap-shape_c            False
# cap-shape_f             True
# cap-shape_o            False
# cap-shape_p            False
# cap-shape_s            False
# cap-shape_x            False
# stem-surface_g         False
# stem-surface_h         False
# stem-surface_i         False
# stem-surface_k         False
# stem-surface_s         False
# stem-surface_t         False
# stem-surface_y         False
# stem-color_e           False
# stem-color_f           False
# stem-color_g           False
# stem-color_k           False
# stem-color_l           False
# stem-color_n           False
# stem-color_o           False
# stem-color_p           False
# stem-color_r           False
# stem-color_u           False
# stem-color_w            True
# stem-color_y           False
# spore-print-color_k    False
# spore-print-color_n    False
# spore-print-color_p    False
# spore-print-color_r    False
# spore-print-color_u    False
# spore-print-color_w    False
#
# Target value (y):
# 0
# Class distribution in final split:
# Series([], Name: proportion, dtype: float64)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.2, random_state=7, shuffle=True
)

# %%
rf = RandomForestClassifier(n_estimators=200, random_state=7, class_weight='balanced')
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=7)

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le_y.classes_))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            e       0.97      0.97      0.97      5465
#            p       0.97      0.98      0.98      6749
#
#     accuracy                           0.97     12214
#    macro avg       0.97      0.97      0.97     12214
# weighted avg       0.97      0.97      0.97     12214

# %%
plt.figure(figsize=(6,5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues",
            xticklabels=le_y.classes_, yticklabels=le_y.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
joblib.dump(rf, "mushroom_rf_model.pkl")
joblib.dump(le_y, "label_encoder.pkl")
# Out:
# ['label_encoder.pkl']

# %%
def predict_mushroom(user_input):
    """
    user_input: dict of feature_name: value
    Example:
    user_input = {
        'cap-diameter'
        'cap-shape'
        'cap-surface'
        'cap-color'
        'gill-attachment'  
        'gill-spacing' 
        'gill-color'  
        'stem-height'
        'stem-width' 
        'stem-root'  
        'stem-surface'  
        'stem-color' 
        'veil-type' 
        'veil-color' 
        'has-ring'  
        'ring-type'
        'spore-print-color'
    }
    Returns: predicted class ('edible'/'poisonous') and probability %
    """
    
    input_df = pd.DataFrame([user_input])

    input_encoded = pd.get_dummies(input_df)

    missing_cols = set(rf.feature_names_in_) - set(input_encoded.columns)
    for col in missing_cols:
        input_encoded[col] = 0
    input_encoded = input_encoded[rf.feature_names_in_]

    prob = rf.predict_proba(input_encoded)[0]
    pred_index = np.argmax(prob)
    pred_class = le_y.classes_[pred_index]

    confidence = prob[pred_index] * 100

    return pred_class, round(confidence, 2)

# %%
pred_class, confidence = predict_mushroom(mushroom_example)
print(f"Prediction: {pred_class}, Confidence: {confidence}%")
# Out:
# Prediction: e, Confidence: 99.5%
